# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

sns.set(style="white", color_codes=True)

x, y = np.random.standard_normal(size=(2, 100))
# iris = sns.load_dataset("iris")
g = sns.JointGrid(data=iris, x="sepal_length", y="petal_length")

g.plot_joint(plt.scatter)
# g = sns.jointplot(x=x, y=y, kind="scatter", marginal_kws={"color": "green"})
# g = g.plot_marginals(sns.kdeplot, color="green", fill=True)
# g = g.plot_marginals(sns.histplot, color="green", fill=True)

sns.histplot(
    iris["sepal_length"].to_numpy(),
    ax=g.ax_marg_x,
    color="red",
    kde=True,
)
plt.show()
# x = np.linspace(
#     stats.norm.ppf(0.001, loc=0, scale=1),
#     stats.norm.ppf(0.999, loc=0, scale=1),
#     500,
# )
# pdf = stats.norm.pdf(x, 0, 1)
# g.ax_marg_x.plot(
#     x, pdf,
#     # alpha=0.5,
#     # range=(np.min(x), np.max(x)),
# )


# plt.plot(df["AGW"].sort_values(), pdf)
# g.ax_marg_y.plot(x, stats.norm.pdf(x, loc=0, scale=1), color="crimson", label="pdf")
# sns.kdeplot(
#     y,
#     ax=g.ax_marg_x,
#     color='red',
# )
# plt.setp(g.ax_marg_y.patches, color="r")
